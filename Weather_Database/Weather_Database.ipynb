# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
from datetime import datetime

# %%
lat = np.random.uniform(low=-90.000, high=90.000, size=2000)
lon = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lon = zip(lat, lon)
lat_lon

# %%
coordinates = list(lat_lon)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 764

# %%
import requests
from config import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
print(requests.get(url))
# Out:
# <Response [400]>

# %%
print(requests.get(url).json())
# Out:
# {'cod': '400', 'message': 'Nothing to geocode'}

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
    
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | thompson
# Processing Record 3 of Set 1 | oistins
# Processing Record 4 of Set 1 | busselton
# Processing Record 5 of Set 1 | vestmannaeyjar
# Processing Record 6 of Set 1 | praia da vitoria
# Processing Record 7 of Set 1 | esil
# Processing Record 8 of Set 1 | hermanus
# Processing Record 9 of Set 1 | klaksvik
# Processing Record 10 of Set 1 | champerico
# Processing Record 11 of Set 1 | kamenskoye
# City not found. Skipping...
# Processing Record 12 of Set 1 | cape town
# Processing Record 13 of Set 1 | georgetown
# Processing Record 14 of Set 1 | henties bay
# Processing Record 15 of Set 1 | muisne
# Processing Record 16 of Set 1 | tuatapere
# Processing Record 17 of Set 1 | cayenne
# Processing Record 18 of Set 1 | porbandar
# Processing Record 19 of Set 1 | tasiilaq
# Processing Record 20 of Set 1 | andenes
# Processing Record 21 of Set 1 | saskylakh
# Processing Record 22 of Set 1 | norman wells
# Processing Record 23 of Set 1 | saint-philippe
# Processing Record 24 of Set 1 | terra nova
# Processing Record 25 of Set 1 | hobart
# Processing Record 26 of Set 1 | rikitea
# Processing Record 27 of Set 1 | bluff
# Processing Record 28 of Set 1 | beloha
# Processing Record 29 of Set 1 | leningradskiy
# Processing Record 30 of Set 1 | yerbogachen
# Processing Record 31 of Set 1 | bengkulu
# Processing Record 32 of Set 1 | podor
# Processing Record 33 of Set 1 | tuktoyaktuk
# Processing Record 34 of Set 1 | vanavara
# Processing Record 35 of Set 1 | saldanha
# Processing Record 36 of Set 1 | mahebourg
# Processing Record 37 of Set 1 | nichinan
# Processing Record 38 of Set 1 | deogarh
# Processing Record 39 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 40 of Set 1 | half moon bay
# Processing Record 41 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 42 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 43 of Set 1 | neutraubling
# Processing Record 44 of Set 1 | husavik
# Processing Record 45 of Set 1 | albany
# Processing Record 46 of Set 1 | chumikan
# Processing Record 47 of Set 1 | aanekoski
# Processing Record 48 of Set 1 | koani
# Processing Record 49 of Set 1 | hithadhoo
# Processing Record 50 of Set 1 | eyl
# Processing Record 1 of Set 2 | peruibe
# Processing Record 2 of Set 2 | ha
# City not found. Skipping...
# Processing Record 3 of Set 2 | castro
# Processing Record 4 of Set 2 | naze
# Processing Record 5 of Set 2 | argelia
# Processing Record 6 of Set 2 | san jose
# Processing Record 7 of Set 2 | jalingo
# Processing Record 8 of Set 2 | sibolga
# Processing Record 9 of Set 2 | santo antonio do ica
# Processing Record 10 of Set 2 | barrow
# Processing Record 11 of Set 2 | severo-kurilsk
# Processing Record 12 of Set 2 | grindavik
# Processing Record 13 of Set 2 | san juan de la maguana
# Processing Record 14 of Set 2 | anadyr
# Processing Record 15 of Set 2 | dikson
# Processing Record 16 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 17 of Set 2 | ushuaia
# Processing Record 18 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 19 of Set 2 | tautira
# Processing Record 20 of Set 2 | inuvik
# Processing Record 21 of Set 2 | vadso
# Processing Record 22 of Set 2 | fethiye
# Processing Record 23 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 2 | puerto ayora
# Processing Record 25 of Set 2 | yate
# Processing Record 26 of Set 2 | coihaique
# Processing Record 27 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 28 of Set 2 | abu zabad
# Processing Record 29 of Set 2 | talnakh
# Processing Record 30 of Set 2 | dekoa
# City not found. Skipping...
# Processing Record 31 of Set 2 | kunigal
# Processing Record 32 of Set 2 | hofn
# Processing Record 33 of Set 2 | pacific grove
# Processing Record 34 of Set 2 | new norfolk
# Processing Record 35 of Set 2 | tazovskiy
# Processing Record 36 of Set 2 | bubaque
# Processing Record 37 of Set 2 | port alfred
# Processing Record 38 of Set 2 | pevek
# Processing Record 39 of Set 2 | kasulu
# Processing Record 40 of Set 2 | saint anthony
# Processing Record 41 of Set 2 | zhigansk
# Processing Record 42 of Set 2 | lebu
# Processing Record 43 of Set 2 | uppsala
# Processing Record 44 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 45 of Set 2 | shitanjing
# Processing Record 46 of Set 2 | airai
# Processing Record 47 of Set 2 | puerto escondido
# Processing Record 48 of Set 2 | goderich
# Processing Record 49 of Set 2 | porto novo
# Processing Record 50 of Set 2 | zhangye
# Processing Record 1 of Set 3 | bredasdorp
# Processing Record 2 of Set 3 | aljezur
# Processing Record 3 of Set 3 | padang
# Processing Record 4 of Set 3 | nsanje
# Processing Record 5 of Set 3 | mackay
# Processing Record 6 of Set 3 | port hawkesbury
# Processing Record 7 of Set 3 | christchurch
# Processing Record 8 of Set 3 | qaanaaq
# Processing Record 9 of Set 3 | okhtyrka
# Processing Record 10 of Set 3 | bambous virieux
# Processing Record 11 of Set 3 | pangnirtung
# Processing Record 12 of Set 3 | roald
# Processing Record 13 of Set 3 | poysdorf
# Processing Record 14 of Set 3 | ouricuri
# Processing Record 15 of Set 3 | nanortalik
# Processing Record 16 of Set 3 | butaritari
# Processing Record 17 of Set 3 | rabo de peixe
# Processing Record 18 of Set 3 | kahului
# Processing Record 19 of Set 3 | puri
# Processing Record 20 of Set 3 | atuona
# Processing Record 21 of Set 3 | guaruja
# Processing Record 22 of Set 3 | east london
# Processing Record 23 of Set 3 | sajanan
# Processing Record 24 of Set 3 | mumford
# Processing Record 25 of Set 3 | jamestown
# Processing Record 26 of Set 3 | gold coast
# Processing Record 27 of Set 3 | kununurra
# Processing Record 28 of Set 3 | arrifes
# Processing Record 29 of Set 3 | hilo
# Processing Record 30 of Set 3 | coahuayana
# Processing Record 31 of Set 3 | kavieng
# Processing Record 32 of Set 3 | faanui
# Processing Record 33 of Set 3 | puerto lopez
# Processing Record 34 of Set 3 | srandakan
# Processing Record 35 of Set 3 | kapaa
# Processing Record 36 of Set 3 | gabu
# Processing Record 37 of Set 3 | punta arenas
# Processing Record 38 of Set 3 | hamina
# Processing Record 39 of Set 3 | cidreira
# Processing Record 40 of Set 3 | soloneshnoye
# Processing Record 41 of Set 3 | aden
# Processing Record 42 of Set 3 | katsuura
# Processing Record 43 of Set 3 | warman
# Processing Record 44 of Set 3 | santa vitoria do palmar
# Processing Record 45 of Set 3 | marsh harbour
# Processing Record 46 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 47 of Set 3 | cheuskiny
# City not found. Skipping...
# Processing Record 48 of Set 3 | grand centre
# City not found. Skipping...
# Processing Record 49 of Set 3 | shingu
# Processing Record 50 of Set 3 | nurota
# Processing Record 1 of Set 4 | avarua
# Processing Record 2 of Set 4 | maraa
# Processing Record 3 of Set 4 | mogocha
# Processing Record 4 of Set 4 | ilulissat
# Processing Record 5 of Set 4 | sechura
# Processing Record 6 of Set 4 | ambilobe
# Processing Record 7 of Set 4 | arraial do cabo
# Processing Record 8 of Set 4 | akyab
# Processing Record 9 of Set 4 | comodoro rivadavia
# Processing Record 10 of Set 4 | codrington
# Processing Record 11 of Set 4 | lagoa
# Processing Record 12 of Set 4 | port keats
# Processing Record 13 of Set 4 | saint-leu
# Processing Record 14 of Set 4 | nikolskoye
# Processing Record 15 of Set 4 | narsaq
# Processing Record 16 of Set 4 | bayshore gardens
# Processing Record 17 of Set 4 | pangkalanbuun
# Processing Record 18 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 19 of Set 4 | pitimbu
# Processing Record 20 of Set 4 | gangotri
# City not found. Skipping...
# Processing Record 21 of Set 4 | kenai
# Processing Record 22 of Set 4 | kiama
# Processing Record 23 of Set 4 | cradock
# Processing Record 24 of Set 4 | barda
# Processing Record 25 of Set 4 | provideniya
# Processing Record 26 of Set 4 | saint george
# Processing Record 27 of Set 4 | mar del plata
# Processing Record 28 of Set 4 | stephenville
# Processing Record 29 of Set 4 | hay river
# Processing Record 30 of Set 4 | nekhayevskiy
# Processing Record 31 of Set 4 | msanga
# Processing Record 32 of Set 4 | rancho palos verdes
# Processing Record 33 of Set 4 | olafsvik
# Processing Record 34 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 35 of Set 4 | nouadhibou
# Processing Record 36 of Set 4 | mount gambier
# Processing Record 37 of Set 4 | lazaro cardenas
# Processing Record 38 of Set 4 | vaini
# Processing Record 39 of Set 4 | havelock
# Processing Record 40 of Set 4 | deputatskiy
# Processing Record 41 of Set 4 | hami
# Processing Record 42 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 43 of Set 4 | waynesville
# Processing Record 44 of Set 4 | upernavik
# Processing Record 45 of Set 4 | lukulu
# Processing Record 46 of Set 4 | mutata
# Processing Record 47 of Set 4 | puerto armuelles
# Processing Record 48 of Set 4 | anju
# Processing Record 49 of Set 4 | juneau
# Processing Record 50 of Set 4 | faya
# Processing Record 1 of Set 5 | kruisfontein
# Processing Record 2 of Set 5 | fairbanks
# Processing Record 3 of Set 5 | chokurdakh
# Processing Record 4 of Set 5 | bathsheba
# Processing Record 5 of Set 5 | longyearbyen
# Processing Record 6 of Set 5 | hokitika
# Processing Record 7 of Set 5 | boralday
# Processing Record 8 of Set 5 | constantine
# Processing Record 9 of Set 5 | dinghai
# Processing Record 10 of Set 5 | karratha
# Processing Record 11 of Set 5 | slave lake
# Processing Record 12 of Set 5 | pueblo nuevo
# Processing Record 13 of Set 5 | digoin
# Processing Record 14 of Set 5 | suzu
# City not found. Skipping...
# Processing Record 15 of Set 5 | ngunguru
# Processing Record 16 of Set 5 | zambezi
# Processing Record 17 of Set 5 | nuuk
# Processing Record 18 of Set 5 | harper
# Processing Record 19 of Set 5 | khatanga
# Processing Record 20 of Set 5 | mahon
# Processing Record 21 of Set 5 | santarem
# Processing Record 22 of Set 5 | laguna
# Processing Record 23 of Set 5 | hambantota
# Processing Record 24 of Set 5 | gezing
# Processing Record 25 of Set 5 | barranca
# Processing Record 26 of Set 5 | ponta do sol
# Processing Record 27 of Set 5 | yellowknife
# Processing Record 28 of Set 5 | arys
# Processing Record 29 of Set 5 | buraydah
# Processing Record 30 of Set 5 | tonstad
# Processing Record 31 of Set 5 | ixtapa
# Processing Record 32 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 33 of Set 5 | arinos
# Processing Record 34 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 35 of Set 5 | bardiyah
# Processing Record 36 of Set 5 | makamba
# Processing Record 37 of Set 5 | buzdyak
# Processing Record 38 of Set 5 | touros
# Processing Record 39 of Set 5 | aitape
# Processing Record 40 of Set 5 | yatou
# Processing Record 41 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 42 of Set 5 | chapais
# Processing Record 43 of Set 5 | san cristobal
# Processing Record 44 of Set 5 | gidole
# Processing Record 45 of Set 5 | paamiut
# Processing Record 46 of Set 5 | praya
# Processing Record 47 of Set 5 | baruun-urt
# Processing Record 48 of Set 5 | chuy
# Processing Record 49 of Set 5 | hope
# Processing Record 50 of Set 5 | vallenar
# Processing Record 1 of Set 6 | bor
# Processing Record 2 of Set 6 | zaraza
# Processing Record 3 of Set 6 | dataganj
# Processing Record 4 of Set 6 | westport
# Processing Record 5 of Set 6 | inderborskiy
# City not found. Skipping...
# Processing Record 6 of Set 6 | qianguo
# Processing Record 7 of Set 6 | lekoni
# Processing Record 8 of Set 6 | lorengau
# Processing Record 9 of Set 6 | kirakira
# Processing Record 10 of Set 6 | bonthe
# Processing Record 11 of Set 6 | eldorado
# Processing Record 12 of Set 6 | eydhafushi
# Processing Record 13 of Set 6 | la ronge
# Processing Record 14 of Set 6 | one hundred mile house
# City not found. Skipping...
# Processing Record 15 of Set 6 | salalah
# Processing Record 16 of Set 6 | sao filipe
# Processing Record 17 of Set 6 | quatre cocos
# Processing Record 18 of Set 6 | jimenez
# Processing Record 19 of Set 6 | mogadishu
# Processing Record 20 of Set 6 | kodiak
# Processing Record 21 of Set 6 | lunenburg
# Processing Record 22 of Set 6 | tumbagaan
# Processing Record 23 of Set 6 | jardim
# Processing Record 24 of Set 6 | dolores
# Processing Record 25 of Set 6 | lima
# Processing Record 26 of Set 6 | port hardy
# Processing Record 27 of Set 6 | borovoy
# Processing Record 28 of Set 6 | panzhihua
# Processing Record 29 of Set 6 | mala
# Processing Record 30 of Set 6 | rawson
# Processing Record 31 of Set 6 | saint-augustin
# Processing Record 32 of Set 6 | teeli
# Processing Record 33 of Set 6 | mbandaka
# Processing Record 34 of Set 6 | carnarvon
# Processing Record 35 of Set 6 | avera
# Processing Record 36 of Set 6 | bilma
# Processing Record 37 of Set 6 | broome
# Processing Record 38 of Set 6 | kamenka
# Processing Record 39 of Set 6 | lahat
# Processing Record 40 of Set 6 | pasighat
# Processing Record 41 of Set 6 | iqaluit
# Processing Record 42 of Set 6 | chilca
# Processing Record 43 of Set 6 | esperance
# Processing Record 44 of Set 6 | kisangani
# Processing Record 45 of Set 6 | lewistown
# Processing Record 46 of Set 6 | rantepao
# Processing Record 47 of Set 6 | namatanai
# Processing Record 48 of Set 6 | yulara
# Processing Record 49 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 50 of Set 6 | sarangani
# Processing Record 1 of Set 7 | vyartsilya
# Processing Record 2 of Set 7 | aykhal
# Processing Record 3 of Set 7 | ust-ishim
# Processing Record 4 of Set 7 | stokmarknes
# Processing Record 5 of Set 7 | toba
# Processing Record 6 of Set 7 | plouzane
# Processing Record 7 of Set 7 | morgan city
# Processing Record 8 of Set 7 | cabo san lucas
# Processing Record 9 of Set 7 | harnai
# Processing Record 10 of Set 7 | sawakin
# Processing Record 11 of Set 7 | turayf
# Processing Record 12 of Set 7 | coos bay
# Processing Record 13 of Set 7 | ugoofaaru
# Processing Record 14 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 15 of Set 7 | larap
# Processing Record 16 of Set 7 | burica
# City not found. Skipping...
# Processing Record 17 of Set 7 | teya
# Processing Record 18 of Set 7 | loviisa
# Processing Record 19 of Set 7 | boysun
# Processing Record 20 of Set 7 | aninoasa
# Processing Record 21 of Set 7 | nome
# Processing Record 22 of Set 7 | hornepayne
# Processing Record 23 of Set 7 | skibotn
# Processing Record 24 of Set 7 | oranjestad
# Processing Record 25 of Set 7 | lompoc
# Processing Record 26 of Set 7 | shumikha
# Processing Record 27 of Set 7 | jalu
# Processing Record 28 of Set 7 | ketchikan
# Processing Record 29 of Set 7 | arkhangelsk
# Processing Record 30 of Set 7 | amahai
# Processing Record 31 of Set 7 | wazzan
# City not found. Skipping...
# Processing Record 32 of Set 7 | galiwinku
# City not found. Skipping...
# Processing Record 33 of Set 7 | kaitangata
# Processing Record 34 of Set 7 | hue
# Processing Record 35 of Set 7 | timra
# Processing Record 36 of Set 7 | luderitz
# Processing Record 37 of Set 7 | ribeira grande
# Processing Record 38 of Set 7 | waingapu
# Processing Record 39 of Set 7 | gombong
# Processing Record 40 of Set 7 | kaspiyskiy
# Processing Record 41 of Set 7 | nurobod
# Processing Record 42 of Set 7 | dabakala
# Processing Record 43 of Set 7 | banjarmasin
# Processing Record 44 of Set 7 | manzanillo
# Processing Record 45 of Set 7 | tombouctou
# Processing Record 46 of Set 7 | vila franca do campo
# Processing Record 47 of Set 7 | erzin
# Processing Record 48 of Set 7 | placido de castro
# Processing Record 49 of Set 7 | nelson bay
# Processing Record 50 of Set 7 | hun
# Processing Record 1 of Set 8 | tampakan
# Processing Record 2 of Set 8 | ciudad bolivar
# Processing Record 3 of Set 8 | barcelona
# Processing Record 4 of Set 8 | djibo
# Processing Record 5 of Set 8 | taoudenni
# Processing Record 6 of Set 8 | hamilton
# Processing Record 7 of Set 8 | bintulu
# Processing Record 8 of Set 8 | baykit
# Processing Record 9 of Set 8 | monrovia
# Processing Record 10 of Set 8 | santa cruz del sur
# Processing Record 11 of Set 8 | berlevag
# Processing Record 12 of Set 8 | ahipara
# Processing Record 13 of Set 8 | nizhnyaya tavda
# Processing Record 14 of Set 8 | chabahar
# Processing Record 15 of Set 8 | mamallapuram
# Processing Record 16 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 17 of Set 8 | high level
# Processing Record 18 of Set 8 | salima
# Processing Record 19 of Set 8 | krasnorechenskiy
# Processing Record 20 of Set 8 | san quintin
# Processing Record 21 of Set 8 | glamoc
# Processing Record 22 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 23 of Set 8 | saint-georges
# Processing Record 24 of Set 8 | najran
# Processing Record 25 of Set 8 | rio gallegos
# Processing Record 26 of Set 8 | kigoma
# Processing Record 27 of Set 8 | basco
# Processing Record 28 of Set 8 | bethel
# Processing Record 29 of Set 8 | kudahuvadhoo
# Processing Record 30 of Set 8 | talaya
# Processing Record 31 of Set 8 | pundaguitan
# Processing Record 32 of Set 8 | srednekolymsk
# Processing Record 33 of Set 8 | aklavik
# Processing Record 34 of Set 8 | maymanak
# City not found. Skipping...
# Processing Record 35 of Set 8 | nemuro
# Processing Record 36 of Set 8 | chara
# Processing Record 37 of Set 8 | sampit
# Processing Record 38 of Set 8 | korla
# Processing Record 39 of Set 8 | port elizabeth
# Processing Record 40 of Set 8 | port lincoln
# Processing Record 41 of Set 8 | powell river
# Processing Record 42 of Set 8 | tessalit
# Processing Record 43 of Set 8 | flin flon
# Processing Record 44 of Set 8 | stutterheim
# Processing Record 45 of Set 8 | igarka
# Processing Record 46 of Set 8 | aksu
# Processing Record 47 of Set 8 | petatlan
# Processing Record 48 of Set 8 | kloulklubed
# Processing Record 49 of Set 8 | ballinrobe
# Processing Record 50 of Set 8 | oktyabrskiy
# Processing Record 1 of Set 9 | balimo
# City not found. Skipping...
# Processing Record 2 of Set 9 | souillac
# Processing Record 3 of Set 9 | arkhangelskoye
# Processing Record 4 of Set 9 | oranjemund
# Processing Record 5 of Set 9 | egvekinot
# Processing Record 6 of Set 9 | san patricio
# Processing Record 7 of Set 9 | cherskiy
# Processing Record 8 of Set 9 | xinyang
# Processing Record 9 of Set 9 | kurilsk
# Processing Record 10 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 11 of Set 9 | oga
# Processing Record 12 of Set 9 | beringovskiy
# Processing Record 13 of Set 9 | flinders
# Processing Record 14 of Set 9 | havoysund
# Processing Record 15 of Set 9 | pop
# Processing Record 16 of Set 9 | wajid
# Processing Record 17 of Set 9 | tabory
# Processing Record 18 of Set 9 | bur gabo
# City not found. Skipping...
# Processing Record 19 of Set 9 | sembakung
# Processing Record 20 of Set 9 | williston
# Processing Record 21 of Set 9 | mrirt
# City not found. Skipping...
# Processing Record 22 of Set 9 | sovetskiy
# Processing Record 23 of Set 9 | ostrovnoy
# Processing Record 24 of Set 9 | orahovac
# Processing Record 25 of Set 9 | mustla
# Processing Record 26 of Set 9 | dalby
# Processing Record 27 of Set 9 | meulaboh
# Processing Record 28 of Set 9 | axim
# Processing Record 29 of Set 9 | vao
# Processing Record 30 of Set 9 | kenora
# Processing Record 31 of Set 9 | parit buntar
# Processing Record 32 of Set 9 | svetlogorsk
# Processing Record 33 of Set 9 | richards bay
# Processing Record 34 of Set 9 | chulym
# Processing Record 35 of Set 9 | marzuq
# Processing Record 36 of Set 9 | alofi
# Processing Record 37 of Set 9 | tura
# Processing Record 38 of Set 9 | saurimo
# Processing Record 39 of Set 9 | kysyl-syr
# Processing Record 40 of Set 9 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 41 of Set 9 | kieta
# Processing Record 42 of Set 9 | nizhniy odes
# Processing Record 43 of Set 9 | abu samrah
# Processing Record 44 of Set 9 | santa maria
# Processing Record 45 of Set 9 | addi ugri
# City not found. Skipping...
# Processing Record 46 of Set 9 | hagi
# Processing Record 47 of Set 9 | northam
# Processing Record 48 of Set 9 | carutapera
# Processing Record 49 of Set 9 | finnsnes
# Processing Record 50 of Set 9 | boende
# Processing Record 1 of Set 10 | springville
# Processing Record 2 of Set 10 | karakose
# City not found. Skipping...
# Processing Record 3 of Set 10 | kungurtug
# Processing Record 4 of Set 10 | podgorica
# Processing Record 5 of Set 10 | severnoye
# Processing Record 6 of Set 10 | ust-ilimsk
# Processing Record 7 of Set 10 | aquiraz
# Processing Record 8 of Set 10 | maloshuyka
# City not found. Skipping...
# Processing Record 9 of Set 10 | spirovo
# Processing Record 10 of Set 10 | ledyard
# Processing Record 11 of Set 10 | fortuna
# Processing Record 12 of Set 10 | tezu
# Processing Record 13 of Set 10 | grao mogol
# Processing Record 14 of Set 10 | gat
# Processing Record 15 of Set 10 | allende
# Processing Record 16 of Set 10 | ormara
# Processing Record 17 of Set 10 | abha
# Processing Record 18 of Set 10 | daru
# Processing Record 19 of Set 10 | felidhoo
# City not found. Skipping...
# Processing Record 20 of Set 10 | janauba
# Processing Record 21 of Set 10 | tual
# Processing Record 22 of Set 10 | abdanan
# Processing Record 23 of Set 10 | paidha
# Processing Record 24 of Set 10 | newport
# Processing Record 25 of Set 10 | conakry
# Processing Record 26 of Set 10 | cazaje
# City not found. Skipping...
# Processing Record 27 of Set 10 | ola
# Processing Record 28 of Set 10 | salto
# Processing Record 29 of Set 10 | tupiza
# Processing Record 30 of Set 10 | lavrentiya
# Processing Record 31 of Set 10 | cravo norte
# Processing Record 32 of Set 10 | sola
# Processing Record 33 of Set 10 | haines junction
# Processing Record 34 of Set 10 | seryshevo
# Processing Record 35 of Set 10 | makakilo city
# Processing Record 36 of Set 10 | geraldton
# Processing Record 37 of Set 10 | okhotsk
# Processing Record 38 of Set 10 | victoria
# Processing Record 39 of Set 10 | murray bridge
# Processing Record 40 of Set 10 | kodinsk
# Processing Record 41 of Set 10 | waitara
# Processing Record 42 of Set 10 | nha trang
# Processing Record 43 of Set 10 | sungaipenuh
# Processing Record 44 of Set 10 | puerto cabezas
# Processing Record 45 of Set 10 | garowe
# Processing Record 46 of Set 10 | comrie
# Processing Record 47 of Set 10 | barcelos
# Processing Record 48 of Set 10 | labuhan
# Processing Record 49 of Set 10 | los llanos de aridane
# Processing Record 50 of Set 10 | wanning
# Processing Record 1 of Set 11 | skalistyy
# City not found. Skipping...
# Processing Record 2 of Set 11 | mariestad
# Processing Record 3 of Set 11 | zhezkazgan
# Processing Record 4 of Set 11 | mujiayingzi
# Processing Record 5 of Set 11 | port angeles
# Processing Record 6 of Set 11 | tatawin
# Processing Record 7 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 8 of Set 11 | shimoda
# Processing Record 9 of Set 11 | campbell river
# Processing Record 10 of Set 11 | taltal
# Processing Record 11 of Set 11 | basoko
# Processing Record 12 of Set 11 | poum
# Processing Record 13 of Set 11 | bukachacha
# Processing Record 14 of Set 11 | taiobeiras
# Processing Record 15 of Set 11 | lingyuan
# Processing Record 16 of Set 11 | grand gaube
# Processing Record 17 of Set 11 | sorong
# Processing Record 18 of Set 11 | hervey bay
# Processing Record 19 of Set 11 | sfantu gheorghe
# Processing Record 20 of Set 11 | borovsk
# Processing Record 21 of Set 11 | batagay-alyta
# Processing Record 22 of Set 11 | atasu
# Processing Record 23 of Set 11 | puerto madryn
# Processing Record 24 of Set 11 | bac lieu
# Processing Record 25 of Set 11 | port-gentil
# Processing Record 26 of Set 11 | maldonado
# Processing Record 27 of Set 11 | cuenca
# Processing Record 28 of Set 11 | mwinilunga
# Processing Record 29 of Set 11 | lasa
# Processing Record 30 of Set 11 | castlemaine
# Processing Record 31 of Set 11 | buchanan
# Processing Record 32 of Set 11 | tallahassee
# Processing Record 33 of Set 11 | arshan
# Processing Record 34 of Set 11 | rabat
# Processing Record 35 of Set 11 | dingle
# Processing Record 36 of Set 11 | tomatlan
# Processing Record 37 of Set 11 | karaton
# Processing Record 38 of Set 11 | namibe
# Processing Record 39 of Set 11 | bahia blanca
# Processing Record 40 of Set 11 | fergus falls
# Processing Record 41 of Set 11 | wanaka
# Processing Record 42 of Set 11 | samarai
# Processing Record 43 of Set 11 | zuenoula
# Processing Record 44 of Set 11 | songjianghe
# Processing Record 45 of Set 11 | melilla
# Processing Record 46 of Set 11 | atar
# Processing Record 47 of Set 11 | akureyri
# Processing Record 48 of Set 11 | sao jose da coroa grande
# Processing Record 49 of Set 11 | portland
# Processing Record 50 of Set 11 | millinocket
# Processing Record 1 of Set 12 | nong han
# Processing Record 2 of Set 12 | tokomaru
# Processing Record 3 of Set 12 | kyra
# Processing Record 4 of Set 12 | sakaiminato
# Processing Record 5 of Set 12 | bulolo
# Processing Record 6 of Set 12 | tiruchchendur
# Processing Record 7 of Set 12 | yeniseysk
# Processing Record 8 of Set 12 | rogovskaya
# Processing Record 9 of Set 12 | sorland
# Processing Record 10 of Set 12 | norrtalje
# Processing Record 11 of Set 12 | cortland
# Processing Record 12 of Set 12 | waipawa
# Processing Record 13 of Set 12 | griffith
# Processing Record 14 of Set 12 | camocim
# Processing Record 15 of Set 12 | clarence town
# Processing Record 16 of Set 12 | whitehorse
# Processing Record 17 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 18 of Set 12 | mimarsinan
# Processing Record 19 of Set 12 | denpasar
# Processing Record 20 of Set 12 | margate
# Processing Record 21 of Set 12 | mayumba
# Processing Record 22 of Set 12 | viligili
# City not found. Skipping...
# Processing Record 23 of Set 12 | matay
# Processing Record 24 of Set 12 | sao gabriel da cachoeira
# Processing Record 25 of Set 12 | sisimiut
# Processing Record 26 of Set 12 | tiksi
# Processing Record 27 of Set 12 | batken
# Processing Record 28 of Set 12 | lunino
# Processing Record 29 of Set 12 | keetmanshoop
# Processing Record 30 of Set 12 | urumqi
# Processing Record 31 of Set 12 | rocha
# Processing Record 32 of Set 12 | gouyave
# Processing Record 33 of Set 12 | hurghada
# Processing Record 34 of Set 12 | bilibino
# Processing Record 35 of Set 12 | saiha
# Processing Record 36 of Set 12 | sayyan
# Processing Record 37 of Set 12 | awbari
# Processing Record 38 of Set 12 | cao bang
# Processing Record 39 of Set 12 | nishihara
# Processing Record 40 of Set 12 | finschhafen
# Processing Record 41 of Set 12 | tawkar
# City not found. Skipping...
# Processing Record 42 of Set 12 | mabaruma
# Processing Record 43 of Set 12 | nyrob
# Processing Record 44 of Set 12 | gimli
# Processing Record 45 of Set 12 | les escoumins
# Processing Record 46 of Set 12 | kushiro
# Processing Record 47 of Set 12 | disa
# Processing Record 48 of Set 12 | tigil
# Processing Record 49 of Set 12 | vostok
# Processing Record 50 of Set 12 | beacon
# Processing Record 1 of Set 13 | la ligua
# Processing Record 2 of Set 13 | college
# Processing Record 3 of Set 13 | pimentel
# Processing Record 4 of Set 13 | winnemucca
# Processing Record 5 of Set 13 | dzhankoy
# Processing Record 6 of Set 13 | portoferraio
# Processing Record 7 of Set 13 | rockland
# Processing Record 8 of Set 13 | ulaangom
# Processing Record 9 of Set 13 | biratnagar
# Processing Record 10 of Set 13 | burns lake
# Processing Record 11 of Set 13 | itarema
# Processing Record 12 of Set 13 | teguise
# Processing Record 13 of Set 13 | sitka
# Processing Record 14 of Set 13 | santa catarina de tepehuanes
# Processing Record 15 of Set 13 | kimbe
# Processing Record 16 of Set 13 | zhigalovo
# Processing Record 17 of Set 13 | susanville
# Processing Record 18 of Set 13 | vangaindrano
# Processing Record 19 of Set 13 | marmaris
# Processing Record 20 of Set 13 | mananjary
# Processing Record 21 of Set 13 | tokur
# Processing Record 22 of Set 13 | tabou
# Processing Record 23 of Set 13 | sidi ali
# Processing Record 24 of Set 13 | te anau
# Processing Record 25 of Set 13 | tchibanga
# Processing Record 26 of Set 13 | batemans bay
# Processing Record 27 of Set 13 | santa cruz
# Processing Record 28 of Set 13 | takoradi
# Processing Record 29 of Set 13 | gondanglegi
# Processing Record 30 of Set 13 | novodugino
# Processing Record 31 of Set 13 | ariquemes
# Processing Record 32 of Set 13 | iralaya
# Processing Record 33 of Set 13 | victor harbor
# Processing Record 34 of Set 13 | riyadh
# Processing Record 35 of Set 13 | nivala
# Processing Record 36 of Set 13 | nyagan
# Processing Record 37 of Set 13 | herre
# Processing Record 38 of Set 13 | moi
# Processing Record 39 of Set 13 | hauterive
# Processing Record 40 of Set 13 | dzhusaly
# City not found. Skipping...
# Processing Record 41 of Set 13 | edson
# Processing Record 42 of Set 13 | neftcala
# Processing Record 43 of Set 13 | sterling
# Processing Record 44 of Set 13 | matagami
# Processing Record 45 of Set 13 | veraval
# Processing Record 46 of Set 13 | bandarbeyla
# Processing Record 47 of Set 13 | oxford
# Processing Record 48 of Set 13 | torbay
# Processing Record 49 of Set 13 | emerald
# Processing Record 50 of Set 13 | shakawe
# Processing Record 1 of Set 14 | sainte-maxime
# Processing Record 2 of Set 14 | paradwip
# City not found. Skipping...
# Processing Record 3 of Set 14 | kutum
# Processing Record 4 of Set 14 | cap malheureux
# Processing Record 5 of Set 14 | savannakhet
# Processing Record 6 of Set 14 | balkanabat
# Processing Record 7 of Set 14 | chenghai
# Processing Record 8 of Set 14 | khani
# Processing Record 9 of Set 14 | grand island
# Processing Record 10 of Set 14 | kalemie
# Processing Record 11 of Set 14 | rio grande
# Processing Record 12 of Set 14 | prince rupert
# Processing Record 13 of Set 14 | storforshei
# Processing Record 14 of Set 14 | mount isa
# Processing Record 15 of Set 14 | baiao
# Processing Record 16 of Set 14 | hareid
# Processing Record 17 of Set 14 | brae
# Processing Record 18 of Set 14 | mehamn
# Processing Record 19 of Set 14 | whitianga
# Processing Record 20 of Set 14 | ondorhaan
# City not found. Skipping...
# Processing Record 21 of Set 14 | kurgan
# Processing Record 22 of Set 14 | soller
# Processing Record 23 of Set 14 | elesbao veloso
# Processing Record 24 of Set 14 | port blair
# Processing Record 25 of Set 14 | mwene-ditu
# Processing Record 26 of Set 14 | reforma
# Processing Record 27 of Set 14 | pisco
# Processing Record 28 of Set 14 | umm kaddadah
# Processing Record 29 of Set 14 | amapa
# Processing Record 30 of Set 14 | alcacer do sal
# Processing Record 31 of Set 14 | isangel
# Processing Record 32 of Set 14 | ouesso
# Processing Record 33 of Set 14 | bhag
# Processing Record 34 of Set 14 | marawi
# Processing Record 35 of Set 14 | avenal
# Processing Record 36 of Set 14 | yakeshi
# Processing Record 37 of Set 14 | belyy yar
# Processing Record 38 of Set 14 | samalaeulu
# City not found. Skipping...
# Processing Record 39 of Set 14 | raton
# Processing Record 40 of Set 14 | xining
# Processing Record 41 of Set 14 | olga
# Processing Record 42 of Set 14 | clyde river
# Processing Record 43 of Set 14 | bang saphan
# Processing Record 44 of Set 14 | geelong
# Processing Record 45 of Set 14 | tahta
# Processing Record 46 of Set 14 | adrar
# Processing Record 47 of Set 14 | fare
# Processing Record 48 of Set 14 | selikhino
# Processing Record 49 of Set 14 | bacolod
# Processing Record 50 of Set 14 | kosh-agach
# Processing Record 1 of Set 15 | kasongo-lunda
# Processing Record 2 of Set 15 | odemis
# City not found. Skipping...
# Processing Record 3 of Set 15 | pasewalk
# Processing Record 4 of Set 15 | coueron
# Processing Record 5 of Set 15 | marion
# Processing Record 6 of Set 15 | dakar
# Processing Record 7 of Set 15 | partizanskoye
# Processing Record 8 of Set 15 | yar-sale
# Processing Record 9 of Set 15 | ancud
# Processing Record 10 of Set 15 | san bernardo
# Processing Record 11 of Set 15 | nanton
# Processing Record 12 of Set 15 | pakokku
# Processing Record 13 of Set 15 | dire
# Processing Record 14 of Set 15 | kaeo
# Processing Record 15 of Set 15 | mattru
# Processing Record 16 of Set 15 | bowen
# Processing Record 17 of Set 15 | goundam
# Processing Record 18 of Set 15 | barguzin
# Processing Record 19 of Set 15 | north platte
# Processing Record 20 of Set 15 | cochrane
# Processing Record 21 of Set 15 | privolzhskiy
# Processing Record 22 of Set 15 | mana
# Processing Record 23 of Set 15 | bernay
# Processing Record 24 of Set 15 | cordoba
# Processing Record 25 of Set 15 | gizo
# Processing Record 26 of Set 15 | achisay
# City not found. Skipping...
# Processing Record 27 of Set 15 | da lat
# Processing Record 28 of Set 15 | merrydale
# Processing Record 29 of Set 15 | alexandria
# Processing Record 30 of Set 15 | salinopolis
# Processing Record 31 of Set 15 | romny
# Processing Record 32 of Set 15 | valparaiso
# Processing Record 33 of Set 15 | moron
# Processing Record 34 of Set 15 | kirby
# Processing Record 35 of Set 15 | kavaratti
# Processing Record 36 of Set 15 | chesma
# Processing Record 37 of Set 15 | staryy nadym
# Processing Record 38 of Set 15 | perbaungan
# Processing Record 39 of Set 15 | korgen
# Processing Record 40 of Set 15 | rafai
# Processing Record 41 of Set 15 | okakarara
# Processing Record 42 of Set 15 | yarmouth
# Processing Record 43 of Set 15 | san andres
# Processing Record 44 of Set 15 | manoleasa
# Processing Record 45 of Set 15 | chengde
# Processing Record 46 of Set 15 | strezhevoy
# Processing Record 47 of Set 15 | madaoua
# Processing Record 48 of Set 15 | general roca
# Processing Record 49 of Set 15 | nathdwara
# Processing Record 50 of Set 15 | lata
# Processing Record 1 of Set 16 | skibbereen
# Processing Record 2 of Set 16 | xuddur
# Processing Record 3 of Set 16 | vardo
# Processing Record 4 of Set 16 | vihti
# Processing Record 5 of Set 16 | eureka
# Processing Record 6 of Set 16 | morro bay
# Processing Record 7 of Set 16 | rognan
# Processing Record 8 of Set 16 | ostuacan
# Processing Record 9 of Set 16 | barbar
# City not found. Skipping...
# Processing Record 10 of Set 16 | dabola
# Processing Record 11 of Set 16 | umzimvubu
# City not found. Skipping...
# Processing Record 12 of Set 16 | ambon
# Processing Record 13 of Set 16 | alice springs
# Processing Record 14 of Set 16 | zheleznodorozhnyy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Mataura -46.1927  168.8643     44.47        91          84
# 1          Thompson  55.7435  -97.8558     84.36        32          20
# 2           Oistins  13.0667  -59.5333     80.69        78          40
# 3         Busselton -33.6500  115.3333     54.45        56          94
# 4    Vestmannaeyjar  63.4427  -20.2734     53.94        91          92
# 5  Praia Da Vitoria  38.7333  -27.0667     74.75       100          90
# 6              Esil  51.9556   66.4042     70.72        64           6
# 7          Hermanus -34.4187   19.2345     56.89        80          95
# 8          Klaksvik  62.2266   -6.5890     47.32        81          65
# 9        Champerico  14.3000  -91.9167     90.14        74          86
#
#    Wind Speed Country                 Date Current Description
# 0        2.37      NZ  2021-08-01 23:18:27       broken clouds
# 1       12.66      CA  2021-08-01 23:22:46               smoke
# 2       10.36      BB  2021-08-01 23:22:46    scattered clouds
# 3        9.01      AU  2021-08-01 23:22:46     overcast clouds
# 4        5.93      IS  2021-08-01 23:22:47     overcast clouds
# 5       14.99      PT  2021-08-01 23:17:47     overcast clouds
# 6        6.78      KZ  2021-08-01 23:22:47           clear sky
# 7        0.54      ZA  2021-08-01 23:22:47     overcast clouds
# 8        6.73      FO  2021-08-01 23:22:48       broken clouds
# 9        4.45      GT  2021-08-01 23:22:48     overcast clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# %%
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0           Mataura      NZ -46.1927  168.8643     44.47        91
# 1          Thompson      CA  55.7435  -97.8558     84.36        32
# 2           Oistins      BB  13.0667  -59.5333     80.69        78
# 3         Busselton      AU -33.6500  115.3333     54.45        56
# 4    Vestmannaeyjar      IS  63.4427  -20.2734     53.94        91
# 5  Praia Da Vitoria      PT  38.7333  -27.0667     74.75       100
# 6              Esil      KZ  51.9556   66.4042     70.72        64
# 7          Hermanus      ZA -34.4187   19.2345     56.89        80
# 8          Klaksvik      FO  62.2266   -6.5890     47.32        81
# 9        Champerico      GT  14.3000  -91.9167     90.14        74
#
#    Cloudiness  Wind Speed Current Description
# 0          84        2.37       broken clouds
# 1          20       12.66               smoke
# 2          40       10.36    scattered clouds
# 3          94        9.01     overcast clouds
# 4          92        5.93     overcast clouds
# 5          90       14.99     overcast clouds
# 6           6        6.78           clear sky
# 7          95        0.54     overcast clouds
# 8          65        6.73       broken clouds
# 9          86        4.45     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
